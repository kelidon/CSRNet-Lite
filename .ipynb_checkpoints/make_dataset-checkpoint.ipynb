# %%
import h5py
import scipy.io as io
import PIL.Image as Image
import numpy as np
import os
import glob
from matplotlib import pyplot as plt
from scipy.ndimage.filters import gaussian_filter 
import scipy
import scipy.spatial
import json
from matplotlib import cm as CM
from image import *
from model import CSRNet
import torch
from tqdm import tqdm
# %matplotlib inline

# %%
# function to create density maps for images
def gaussian_filter_density(gt):
    print (gt.shape)
    density = np.zeros(gt.shape, dtype=np.float32)
    gt_count = np.count_nonzero(gt)
    if gt_count == 0:
        return density

    pts = np.array(list(zip(np.nonzero(gt)[1], np.nonzero(gt)[0])))
    leafsize = 4096
    # build kdtree
    tree = scipy.spatial.KDTree(pts.copy(), leafsize=leafsize)
    # query kdtree
    distances, locations = tree.query(pts, k=2)

    print ('generate density...')
    for i, pt in enumerate(pts):
        pt2d = np.zeros(gt.shape, dtype=np.float32)
        pt2d[pt[1],pt[0]] = 1.
        if gt_count > 1:
            sigma = (distances[i][1]+distances[i][2]+distances[i][3])*0.1
        else:
            sigma = np.average(np.array(gt.shape))/2./2. #case: 1 point
        density += scipy.ndimage.filters.gaussian_filter(pt2d, sigma, mode='constant')
    print ('done.')
    return density

# %%
#set the root to the Shanghai dataset you download
root = 'M:/{code}/CSRNet/CSRNet-pytorch/'

# %%
part_A_train = os.path.join(root,'part_A_final/train_data','images')
part_A_test = os.path.join(root,'part_A_final/test_data','images')
part_B_train = os.path.join(root,'part_B_final/train_data','images')
part_B_test = os.path.join(root,'part_B_final/test_data','images')
path_sets = [part_A_train,part_A_test]

# %%
img_paths = []
print(os.path)
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)
        print(img_path)
# Out:
# <module 'ntpath' from 'M:\\anaconda\\lib\\ntpath.py'>
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_1.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_10.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_100.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_101.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_102.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_103.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_104.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_105.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_106.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_107.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_108.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_109.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_11.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_110.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_111.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_112.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_113.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_114.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_115.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_116.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_117.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_118.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_119.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_12.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_120.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_121.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_122.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_123.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_124.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_125.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_126.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_127.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_128.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_129.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_13.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_130.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_131.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_132.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_133.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_134.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_135.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_136.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_137.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_138.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_139.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_14.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_140.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_141.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_142.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_143.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_144.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_145.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_146.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_147.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_148.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_149.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_15.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_150.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_151.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_152.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_153.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_154.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_155.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_156.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_157.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_158.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_159.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_16.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_160.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_161.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_162.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_163.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_164.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_165.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_166.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_167.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_168.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_169.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_17.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_170.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_171.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_172.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_173.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_174.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_175.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_176.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_177.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_178.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_179.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_18.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_180.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_181.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_182.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_183.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_184.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_185.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_186.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_187.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_188.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_189.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_19.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_190.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_191.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_192.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_193.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_194.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_195.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_196.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_197.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_198.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_199.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_2.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_20.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_200.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_201.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_202.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_203.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_204.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_205.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_206.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_207.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_208.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_209.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_21.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_210.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_211.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_212.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_213.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_214.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_215.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_216.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_217.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_218.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_219.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_22.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_220.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_221.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_222.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_223.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_224.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_225.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_226.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_227.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_228.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_229.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_23.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_230.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_231.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_232.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_233.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_234.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_235.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_236.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_237.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_238.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_239.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_24.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_240.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_241.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_242.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_243.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_244.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_245.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_246.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_247.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_248.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_249.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_25.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_250.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_251.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_252.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_253.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_254.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_255.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_256.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_257.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_258.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_259.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_26.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_260.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_261.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_262.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_263.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_264.jpg
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG

# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_233.jpg
# (768, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_234.jpg
# (768, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_235.jpg
# (683, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_236.jpg
# (768, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_237.jpg
# (432, 700)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_238.jpg
# (469, 709)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_239.jpg
# (328, 605)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_24.jpg
# (769, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_240.jpg
# (183, 464)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_241.jpg
# (728, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_242.jpg
# (667, 1000)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_243.jpg
# (681, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_244.jpg
# (342, 608)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_245.jpg
# (825, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_246.jpg
# (267, 400)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_247.jpg
# (681, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_248.jpg
# (681, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_249.jpg
# (451, 800)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_25.jpg
# (768, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_250.jpg
# (681, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_251.jpg
# (661, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_252.jpg
# (400, 600)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_253.jpg
# (686, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_254.jpg
# (683, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_255.jpg
# (701, 749)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_256.jpg
# (576, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_257.jpg
# (768, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_258.jpg
# (768, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_259.jpg
# (338, 506)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_26.jpg
# (716, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_260.jpg
# (681, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_261.jpg
# (359, 478)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_262.jpg
# (576, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_263.jpg
# (453, 680)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_264.jpg
# (576, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_265.jpg
# (464, 370)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_266.jpg
# (391, 630)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_267.jpg
# (521, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_268.jpg
# (600, 900)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_269.jpg
# (400, 600)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_27.jpg
# (572, 945)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_270.jpg
# (300, 416)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_271.jpg
# (438, 736)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_272.jpg
# (478, 359)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_273.jpg
# (598, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_274.jpg
# (681, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_275.jpg
# (270, 360)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_276.jpg
# (768, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_277.jpg
# (692, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_278.jpg
# (620, 620)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_279.jpg
# (294, 488)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_28.jpg
# (375, 500)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_280.jpg
# (768, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_281.jpg
# (680, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_282.jpg
# (768, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_283.jpg
# (661, 1024)
# generate density...
# done.
# M:/{code}/CSRNet/CSRNet-pytorch/part_A_final/train_data\images\IMG_284.jpg
# (768, 1024)
# generate density...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-2f11adf9ee13> in <module>
#       8         if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
#       9             k[int(gt[i][1]),int(gt[i][0])]=1
# ---> 10     k = gaussian_filter_density(k)
#      11     with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground_truth'), 'w') as hf:
#      12             hf['density'] = k
#
# <ipython-input-9-5249dfb3137a> in gaussian_filter_density(gt)
#      22         else:
#      23             sigma = np.average(np.array(gt.shape))/2./2. #case: 1 point
# ---> 24         density += scipy.ndimage.filters.gaussian_filter(pt2d, sigma, mode='constant')
#      25     print ('done.')
#      26     return density
#
# M:\anaconda\lib\site-packages\scipy\ndimage\filters.py in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     296     if len(axes) > 0:
#     297         for axis, sigma, order, mode in axes:
# --> 298             gaussian_filter1d(input, sigma, axis, order, output,
#     299                               mode, cval, truncate)
#     300             input = output
#
# M:\anaconda\lib\site-packages\scipy\ndimage\filters.py in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     215     # Since we are calling correlate, not convolve, revert the kernel
#     216     weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 217     return correlate1d(input, weights, axis, output, mode, cval, 0)
#     218
#     219
#
# M:\anaconda\lib\site-packages\scipy\ndimage\filters.py in correlate1d(input, weights, axis, output, mode, cval, origin)
#      92                          '(len(weights)-1) // 2')
#      93     mode = _ni_support._extend_mode_to_code(mode)
# ---> 94     _nd_image.correlate1d(input, weights, axis, output, mode, cval,
#      95                           origin)
#      96     return output
#
# KeyboardInterrupt:

# %%
plt.imshow(Image.open(img_paths[1]))

# %%
gt_file = h5py.File(img_paths[0].replace('.jpg','.h5').replace('images','ground_truth'),'r')
groundtruth = np.asarray(gt_file['density'])
plt.imshow(groundtruth,cmap=CM.jet)

# %%
np.sum(groundtruth)
# Out:
# 1543.841

# %%
#now generate the ShanghaiB's ground truth
path_sets = [part_B_train,part_B_test]

# %%
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path